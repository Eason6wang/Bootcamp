# %%
from numpy import exp, array, random, dot
import matplotlib.pyplot as plt

class SingleNeuron():
    def __init__(self):
        # It will give the same random numbers every time
        random.seed(1)

        # random.random((2, 1)) give 2x1 matrix, with range (0,1)
        ''''''
        self.weights

    # The Sigmoid function
    def sigmoid(self, x):
        ''''''
        return

    # The derivative of the Sigmoid function
    def sigmoid_derivative(self, x):
        ''''''
        return
    
    # Forward propagation
    def forward(self, inputs):
        # Summation of dot products, then apply activation function
        ''''''
        return

    # Training
    def train(self, inputs, labels, num_of_iter):
        for iteration in range(num_of_iter):
            # Forward propagation
            logits = self.forward(inputs)

            # Cost function
            cost = labels - logits

            # Backpropagation
            learning_rate = 0.1
            backprop_updates = dot(inputs.T, learning_rate * cost * self.sigmoid_derivative(logits))

            # Update the weights.
            self.weights += backprop_updates

if __name__ == "__main__":

    #Single neuron neural network.
    nn = SingleNeuron()

    print("Randomly initialized weights: " + str(nn.weights))

    training_set = array([[0, 0], [1, 0], [0, 1], [1, 1]])
    labels = array([[0, 0, 1, 1]]).T

    nn.train(training_set, labels, 1000)

    print("Learned weights: " + str(nn.weights))

    # Prediction
    print("Prediction result: " + str(nn.forward(array([2,2]))))
    
    # Visualize
    ''''''
# Out:
# Randomly initialized weights: [[0.417022  ]
#  [0.72032449]]
# Learned weights: [[-1.79604371]
#  [ 3.85949139]]
# Prediction result: [0.98412325]
